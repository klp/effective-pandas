# %% [markdown]
# # Series Deep Dive

# %% [markdown]
# ## 5.1 Loading the data
#
# Not only can `read_csv()` method read csvs, but it can also pull in zip files!

# %%
import pandas as pd

# %%
url = 'https://github.com/mattharrison/datasets/raw/master/data/vehicles.csv.zip'

# %%
df = pd.read_csv(url)
# Out:
# /var/folders/mt/_tmbg5sj039gf4rlsp9gr4pc0000gn/T/ipykernel_7075/4176769558.py:1: DtypeWarning: Columns (68,70,71,72,73,74,76,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)
